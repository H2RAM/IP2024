# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('j.png',0)
kernel = np.ones((5,5),np.uint8)
erosion = cv2.erode(img,kernel,iterations = 1)
plt.subplot(121),plt.imshow(img),plt.title('input')
plt.subplot(122),plt.imshow(erosion),plt.title('output')
# Out:
# (<Axes: title={'center': 'output'}>,
#  <matplotlib.image.AxesImage at 0x2ca276481f0>,
#  Text(0.5, 1.0, 'output'))

# %%
dilation = cv2.dilate(img,kernel,iterations = 1)
plt.subplot(122),plt.imshow(dilation)
# Out:
# (<Axes: >, <matplotlib.image.AxesImage at 0x2ca279fbb80>)

# %%
opening = cv2.morphologyEx(img, cv2.MORPH_OPEN, kernel)
plt.subplot(122),plt.imshow(opening)
# Out:
# (<Axes: >, <matplotlib.image.AxesImage at 0x2ca28b969d0>)

# %%
closing = cv2.morphologyEx(img, cv2.MORPH_CLOSE, kernel)
plt.subplot(122),plt.imshow(closing)
# Out:
# (<Axes: >, <matplotlib.image.AxesImage at 0x2ca27ae1880>)

# %%
gradient = cv2.morphologyEx(img, cv2.MORPH_GRADIENT, kernel)
plt.subplot(122),plt.imshow(gradient)
# Out:
# (<Axes: >, <matplotlib.image.AxesImage at 0x2ca27aaf3d0>)

# %%
tophat = cv2.morphologyEx(img, cv2.MORPH_TOPHAT, kernel)
plt.subplot(122),plt.imshow(tophat)
# Out:
# (<Axes: >, <matplotlib.image.AxesImage at 0x2ca27b8efd0>)

# %%
blackhat = cv2.morphologyEx(img, cv2.MORPH_BLACKHAT, kernel)
plt.subplot(122),plt.imshow(blackhat)
# Out:
# (<Axes: >, <matplotlib.image.AxesImage at 0x2ca28d71730>)
